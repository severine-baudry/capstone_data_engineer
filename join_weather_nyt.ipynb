# %%
import configparser
import os
import pyspark
from pyspark import SparkConf
from pyspark.sql import SparkSession
import pyspark.sql.functions as F
import pyspark.sql.types as T
import pandas as pd
import matplotlib.pyplot as plt
from datetime import date, timedelta

# %%
config = configparser.ConfigParser()
config.read("capstone.cfg")
# Out:
# ['capstone.cfg']

# %%
# add driver postgress to enable to load from existing postgres DB
spark = SparkSession \
    .builder \
    .appName("filter_weather") \
    .config("spark.jars", "postgresql-42.2.18.jar")\
    .config( "spark.driver.extraClassPath", "postgresql-42.2.18.jar")\
    .getOrCreate()

# %%
project_path = config["PATH"]["PROJECT"]

# %%
nyt_path = os.path.join(project_path, "DATA", "us-counties.txt")

# %%
nyt = pd.read_csv(nyt_path,  sep = ",")

# %%
nyt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1124916 entries, 0 to 1124915
# Data columns (total 6 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   date    1124916 non-null  object
#  1   county  1124916 non-null  object
#  2   state   1124916 non-null  object
#  3   fips    1114603 non-null  float64
#  4   cases   1124916 non-null  int64
#  5   deaths  1100383 non-null  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 51.5+ MB

# %%
nyt.sort_values("date", ascending = True, inplace = True)

# %%
l_elements = ["TMIN", "TMAX", "TAVG", "PRCP", "SNOW", "SNWD"]

# %%
l_dates = nyt["date"].unique()

# %%
#nyt[l_elemnts] = np.nan

# %%
nyt
# Out:
#                date      county       state     fips  cases  deaths
# 0        2020-01-21   Snohomish  Washington  53061.0      1     0.0
# 1        2020-01-22   Snohomish  Washington  53061.0      1     0.0
# 2        2020-01-23   Snohomish  Washington  53061.0      1     0.0
# 3        2020-01-24        Cook    Illinois  17031.0      1     0.0
# 4        2020-01-24   Snohomish  Washington  53061.0      1     0.0
# ...             ...         ...         ...      ...    ...     ...
# 1122755  2021-03-15    Metcalfe    Kentucky  21169.0    986    21.0
# 1122756  2021-03-15      Monroe    Kentucky  21171.0   1254    38.0
# 1122757  2021-03-15  Montgomery    Kentucky  21173.0   2355    27.0
# 1122747  2021-03-15      Martin    Kentucky  21159.0    962    14.0
# 1124915  2021-03-15      Weston     Wyoming  56045.0    631     5.0
#
# [1124916 rows x 6 columns]

# %%
weather_path = os.path.join(project_path, "OUT_DATA", "filtered_weather")
d_nyt_elem ={}
for elem in l_elements:
    print(elem)
    elem_path = os.path.join(weather_path, f"element={elem}")
    if not os.path.exists(weather_path):
        print(f"path {weather_path} does not exist")
    if not os.path.exists(elem_path):
        print(f"path {elem_path} does not exist")
    l_df = []
    prev_month = 0
    for date in l_dates :
        pd_date = pd.to_datetime(date)
        if pd_date.month != prev_month:
            print(date)
        prev_month = pd_date.month
        #print(pd_date.year, pd_date.month, pd_date.day)
        date_path = os.path.join(elem_path, f"date={pd_date.year}{pd_date.month:02d}{pd_date.day:02d}")
        if not os.path.exists(date_path):
            print(f"path {date_path} does not exist")
            continue
        #nyt.loc[ nyt["date"] == date, elem ]
        #sp_weather = spark.read.load(date_path, format = "parquet")
        #sp_weather.printSchema()
        weather = pd.read_parquet(date_path)
        l_df.append( pd.merge( nyt[nyt["date"] == date], weather, how = "left", 
                                    left_on = ["county", "state", "fips"],
                                    right_on = ["county", "state_gazeeter", "fips"])
                   )
    print("CONCATENATE")
    d_nyt_elem[elem] = pd.concat(l_df)
# Out:
# TMIN
# 2020-01-21
# 2020-02-01
# 2020-03-01
# 2020-04-01
# 2020-05-01
# 2020-06-01
# 2020-07-01
# 2020-08-01
# 2020-09-01
# 2020-10-01
# 2020-11-01
# 2020-12-01
# 2021-01-01
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210101 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210102 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210103 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210104 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210105 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210106 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210107 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210108 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210109 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210110 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210111 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210112 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210113 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210114 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210115 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210116 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210117 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210118 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210119 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210120 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210121 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210122 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210123 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210124 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210125 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210126 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210127 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210128 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210129 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210130 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210131 does not exist
# 2021-02-01
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210201 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210202 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210203 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210204 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210205 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210206 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210207 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210208 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210209 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210210 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210211 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210212 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210213 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210214 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210215 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210216 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210217 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210218 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210219 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210220 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210221 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210222 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210223 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210224 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210225 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210226 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210227 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210228 does not exist
# 2021-03-01
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210301 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210302 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210303 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210304 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210305 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210306 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210307 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210308 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210309 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210310 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210311 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210312 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210313 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210314 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMIN/date=20210315 does not exist
# CONCATENATE
# TMAX
# 2020-01-21
# 2020-02-01
# 2020-03-01
# 2020-04-01
# 2020-05-01
# 2020-06-01
# 2020-07-01
# 2020-08-01
# 2020-09-01
# 2020-10-01
# 2020-11-01
# 2020-12-01
# 2021-01-01
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210101 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210102 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210103 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210104 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210105 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210106 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210107 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210108 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210109 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210110 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210111 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210112 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210113 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210114 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210115 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210116 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210117 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210118 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210119 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210120 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210121 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210122 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210123 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210124 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210125 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210126 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210127 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210128 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210129 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210130 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210131 does not exist
# 2021-02-01
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210201 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210202 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210203 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210204 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210205 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210206 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210207 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210208 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210209 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210210 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210211 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210212 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210213 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210214 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210215 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210216 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210217 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210218 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210219 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210220 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210221 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210222 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210223 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210224 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210225 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210226 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210227 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210228 does not exist
# 2021-03-01
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210301 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210302 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210303 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210304 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210305 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210306 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210307 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210308 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210309 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210310 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210311 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210312 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210313 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210314 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TMAX/date=20210315 does not exist
# CONCATENATE
# TAVG
# 2020-01-21
# 2020-02-01
# 2020-03-01
# 2020-04-01
# 2020-05-01
# 2020-06-01
# 2020-07-01
# 2020-08-01
# 2020-09-01
# 2020-10-01
# 2020-11-01
# 2020-12-01
# 2021-01-01
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210101 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210102 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210103 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210104 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210105 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210106 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210107 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210108 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210109 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210110 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210111 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210112 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210113 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210114 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210115 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210116 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210117 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210118 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210119 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210120 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210121 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210122 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210123 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210124 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210125 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210126 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210127 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210128 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210129 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210130 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210131 does not exist
# 2021-02-01
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210201 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210202 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210203 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210204 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210205 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210206 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210207 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210208 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210209 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210210 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210211 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210212 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210213 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210214 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210215 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210216 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210217 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210218 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210219 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210220 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210221 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210222 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210223 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210224 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210225 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210226 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210227 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210228 does not exist
# 2021-03-01
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210301 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210302 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210303 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210304 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210305 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210306 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210307 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210308 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210309 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210310 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210311 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210312 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210313 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210314 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=TAVG/date=20210315 does not exist
# CONCATENATE
# PRCP
# 2020-01-21
# 2020-02-01
# 2020-03-01
# 2020-04-01
# 2020-05-01
# 2020-06-01
# 2020-07-01
# 2020-08-01
# 2020-09-01
# 2020-10-01
# 2020-11-01
# 2020-12-01
# 2021-01-01
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210101 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210102 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210103 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210104 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210105 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210106 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210107 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210108 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210109 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210110 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210111 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210112 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210113 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210114 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210115 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210116 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210117 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210118 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210119 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210120 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210121 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210122 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210123 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210124 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210125 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210126 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210127 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210128 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210129 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210130 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210131 does not exist
# 2021-02-01
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210201 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210202 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210203 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210204 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210205 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210206 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210207 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210208 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210209 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210210 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210211 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210212 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210213 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210214 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210215 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210216 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210217 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210218 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210219 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210220 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210221 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210222 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210223 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210224 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210225 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210226 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210227 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210228 does not exist
# 2021-03-01
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210301 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210302 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210303 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210304 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210305 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210306 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210307 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210308 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210309 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210310 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210311 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210312 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210313 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210314 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=PRCP/date=20210315 does not exist
# CONCATENATE
# SNOW
# 2020-01-21
# 2020-02-01
# 2020-03-01
# 2020-04-01
# 2020-05-01
# 2020-06-01
# 2020-07-01
# 2020-08-01
# 2020-09-01
# 2020-10-01
# 2020-11-01
# 2020-12-01
# 2021-01-01
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210101 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210102 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210103 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210104 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210105 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210106 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210107 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210108 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210109 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210110 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210111 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210112 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210113 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210114 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210115 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210116 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210117 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210118 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210119 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210120 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210121 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210122 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210123 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210124 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210125 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210126 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210127 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210128 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210129 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210130 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210131 does not exist
# 2021-02-01
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210201 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210202 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210203 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210204 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210205 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210206 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210207 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210208 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210209 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210210 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210211 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210212 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210213 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210214 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210215 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210216 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210217 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210218 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210219 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210220 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210221 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210222 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210223 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210224 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210225 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210226 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210227 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210228 does not exist
# 2021-03-01
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210301 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210302 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210303 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210304 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210305 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210306 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210307 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210308 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210309 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210310 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210311 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210312 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210313 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210314 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNOW/date=20210315 does not exist
# CONCATENATE
# SNWD
# 2020-01-21
# 2020-02-01
# 2020-03-01
# 2020-04-01
# 2020-05-01
# 2020-06-01
# 2020-07-01
# 2020-08-01
# 2020-09-01
# 2020-10-01
# 2020-11-01
# 2020-12-01
# 2021-01-01
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210101 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210102 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210103 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210104 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210105 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210106 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210107 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210108 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210109 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210110 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210111 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210112 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210113 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210114 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210115 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210116 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210117 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210118 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210119 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210120 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210121 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210122 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210123 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210124 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210125 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210126 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210127 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210128 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210129 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210130 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210131 does not exist
# 2021-02-01
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210201 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210202 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210203 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210204 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210205 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210206 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210207 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210208 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210209 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210210 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210211 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210212 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210213 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210214 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210215 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210216 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210217 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210218 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210219 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210220 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210221 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210222 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210223 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210224 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210225 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210226 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210227 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210228 does not exist
# 2021-03-01
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210301 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210302 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210303 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210304 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210305 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210306 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210307 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210308 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210309 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210310 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210311 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210312 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210313 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210314 does not exist
# path /home/severine/MOOCS/UDACITY/BIG_DATA/CAPSTONE_PROJECT/OUT_DATA/filtered_weather/element=SNWD/date=20210315 does not exist
# CONCATENATE

# %%
d_nyt_elem["PRCP"]
# Out:
#             date      county       state     fips  cases  deaths  \
# 0     2020-01-21   Snohomish  Washington  53061.0      1     0.0
# 0     2020-01-22   Snohomish  Washington  53061.0      1     0.0
# 0     2020-01-23   Snohomish  Washington  53061.0      1     0.0
# 0     2020-01-24        Cook    Illinois  17031.0      1     0.0
# 1     2020-01-24   Snohomish  Washington  53061.0      1     0.0
# ...          ...         ...         ...      ...    ...     ...
# 3240  2020-12-31  Montgomery    Kentucky  21173.0   1378    12.0
# 3241  2020-12-31       Meade    Kentucky  21163.0   1133     4.0
# 3242  2020-12-31      McLean    Kentucky  21149.0    549    21.0
# 3243  2020-12-31       Lewis    Kentucky  21135.0    775    23.0
# 3244  2020-12-31     Menifee    Kentucky  21165.0    215     1.0
#
#      state_gazeeter   station_id   v1
# 0        Washington  US1WASN0091   64
# 0        Washington  US1WASN0091   64
# 0        Washington  US1WASN0091  147
# 0          Illinois  US1ILCK0074   74
# 1        Washington  US1WASN0091   64
# ...             ...          ...  ...
# 3240       Kentucky  USC00155640  157
# 3241       Kentucky  US1KYMD0002  353
# 3242            NaN          NaN  NaN
# 3243       Kentucky  US1KYLW0003  145
# 3244       Kentucky  USC00152791  122
#
# [884737 rows x 9 columns]
