# %% [markdown]
# Load covid cases per population group from CDC (https://data.cdc.gov/Case-Surveillance/COVID-19-Case-Surveillance-Public-Use-Data/vbim-akqf)
# The data list all individual cases (deidentified), with information on sex, age group, race and identity, and date of case, plus some additional information (hospitalisation, intensive care, death ...).
# As the dataset is huge (20.6 Mrows at mid-march), and since their are many identical rows (because of deidentification), we query the data through the api, grouped by the categories we're interested in. Thus, the downloaded dataset remains relatively small.

# %%
#!pip install sodapy
# Out:
# Requirement already satisfied: sodapy in /home/user/anaconda3/envs/airflow/lib/python3.7/site-packages (2.1.0)
# Requirement already satisfied: requests>=2.20.0 in /home/user/anaconda3/envs/airflow/lib/python3.7/site-packages (from sodapy) (2.25.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/user/anaconda3/envs/airflow/lib/python3.7/site-packages (from requests>=2.20.0->sodapy) (1.25.11)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/user/anaconda3/envs/airflow/lib/python3.7/site-packages (from requests>=2.20.0->sodapy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/user/anaconda3/envs/airflow/lib/python3.7/site-packages (from requests>=2.20.0->sodapy) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /home/user/anaconda3/envs/airflow/lib/python3.7/site-packages (from requests>=2.20.0->sodapy) (2.10)
# WARNING: You are using pip version 20.2.4; however, version 21.1.1 is available.
# You should consider upgrading via the '/home/user/anaconda3/envs/airflow/bin/python -m pip install --upgrade pip' command.

# %%
import pandas as pd
from sodapy import Socrata
import configparser
import json
import os
from datetime import datetime

# %% [markdown]
# Without an application token, the size of the downloaded data is limited (see https://dev.socrata.com/docs/app-tokens.html).
#
# CDC uses the [Socrata Open Data API](https://dev.socrata.com/) to manage access to its data. To increase download capabilities, you have to create an AppToken.
#
# First, [create a Socrata account](https://data.cdc.gov/signup).
#
# Then, [sign in](https://data.cdc.gov/login) to Socrata, using the Socrata ID field. Go to 'My Profile', then 'Edit profile', then tab 'Developer settings' (https://data.cdc.gov/profile/edit/developer_settings). Create an AppToken by following [this guide](https://support.socrata.com/hc/en-us/articles/210138558-Generating-an-App-Token).
#
# Then store the AppToken into the config file `capstone.cfg` :
# ```
# [CDC]
# APPTOKEN=<MyAppToken>
# ```

# %% [markdown]
# ## Connect to cdc data server

# %%
config = configparser.ConfigParser()
config.read("capstone.cfg")
# Out:
# ['capstone.cfg']

# %%
# Connect to CDC using AppToken for Socrata API
# set timeout to 100, since the query of such large dataset may take longer time tat default timeout
app_token = config["CDC"]["APPTOKEN"]
client = Socrata("data.cdc.gov",
                 app_token,
                timeout = 100)

# %%
# identifier of CDC dataset with covid case surveillance (https://data.cdc.gov/Case-Surveillance/COVID-19-Case-Surveillance-Public-Use-Data/vbim-akqf)
cdc_dataset_identifier = "vbim-akqf"

# %% [markdown]
# Column names of the data set. We will use only sex, age, ethnicity and date.

# %%
metadata = client.get_metadata(cdc_dataset_identifier)
[x['name'] for x in metadata['columns']]
# Out:
# ['cdc_case_earliest_dt ',
#  'cdc_report_dt',
#  'pos_spec_dt',
#  'onset_dt',
#  'current_status',
#  'sex',
#  'age_group',
#  'race_ethnicity_combined',
#  'hosp_yn',
#  'icu_yn',
#  'death_yn',
#  'medcond_yn']

# %% [markdown]
# documentation about Socrata API is available [here](https://dev.socrata.com/docs/queries/). Some exemple uses of the python client library  [sodapy](https://github.com/xmunoz/sodapy) can be found [here](https://github.com/xmunoz/sodapy/blob/master/examples/soql_queries.ipynb)

# %% [markdown]
# ## Download cases data for a given date

# %%
selected_date = datetime(2021, 4,1)
str_date = selected_date.isoformat() + ".000"
str_date
# Out:
# '2021-04-01T00:00:00.000'

# %%
# iso format with millisecond set to .000
str_date = selected_date.strftime( "%Y-%m-%d") + "T00:00:00.000"
str_date
# Out:
# '2021-04-01T00:00:00.000'

# %%
f"cdc_case_earliest_dt = '{str_date}'"
# Out:
# "cdc_case_earliest_dt = '2021-04-01T00:00:00.000'"

# %%
cases_per_date = client.get(cdc_dataset_identifier,
                           group = "cdc_case_earliest_dt, sex, age_group, race_ethnicity_combined",
                           select = "cdc_case_earliest_dt, sex, age_group, race_ethnicity_combined, count(*)"
                           ,where = f"cdc_case_earliest_dt = '{str_date}'",
                            content_type = "json"
                           )

# %%
len(cases_per_date)
# Out:
# 242

# %%
cases_per_date
# Out:
# [{'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '30 - 39 Years',
#   'race_ethnicity_combined': 'American Indian/Alaska Native, Non-Hispanic',
#   'count': '9'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '50 - 59 Years',
#   'race_ethnicity_combined': 'Hispanic/Latino',
#   'count': '371'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '20 - 29 Years',
#   'race_ethnicity_combined': 'Black, Non-Hispanic',
#   'count': '385'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '20 - 29 Years',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '1624'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '0 - 9 Years',
#   'race_ethnicity_combined': 'White, Non-Hispanic',
#   'count': '490'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '60 - 69 Years',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '585'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '60 - 69 Years',
#   'race_ethnicity_combined': 'Multiple/Other, Non-Hispanic',
#   'count': '102'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '30 - 39 Years',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '1372'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': 'Missing',
#   'race_ethnicity_combined': 'White, Non-Hispanic',
#   'count': '6'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '30 - 39 Years',
#   'race_ethnicity_combined': 'Missing',
#   'count': '80'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '40 - 49 Years',
#   'race_ethnicity_combined': 'American Indian/Alaska Native, Non-Hispanic',
#   'count': '1'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '70 - 79 Years',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '6'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '40 - 49 Years',
#   'race_ethnicity_combined': 'Multiple/Other, Non-Hispanic',
#   'count': '1'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Missing',
#   'age_group': '60 - 69 Years',
#   'race_ethnicity_combined': 'Multiple/Other, Non-Hispanic',
#   'count': '1'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '60 - 69 Years',
#   'race_ethnicity_combined': 'Missing',
#   'count': '38'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '60 - 69 Years',
#   'race_ethnicity_combined': 'Multiple/Other, Non-Hispanic',
#   'count': '96'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': 'Missing',
#   'race_ethnicity_combined': 'White, Non-Hispanic',
#   'count': '2'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': 'Missing',
#   'race_ethnicity_combined': 'Hispanic/Latino',
#   'count': '5'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '70 - 79 Years',
#   'race_ethnicity_combined': 'White, Non-Hispanic',
#   'count': '388'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': 'Missing',
#   'race_ethnicity_combined': 'Black, Non-Hispanic',
#   'count': '4'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '30 - 39 Years',
#   'race_ethnicity_combined': 'Multiple/Other, Non-Hispanic',
#   'count': '218'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Missing',
#   'age_group': '60 - 69 Years',
#   'race_ethnicity_combined': 'Black, Non-Hispanic',
#   'count': '1'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '30 - 39 Years',
#   'race_ethnicity_combined': 'Black, Non-Hispanic',
#   'count': '1'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '0 - 9 Years',
#   'race_ethnicity_combined': 'Black, Non-Hispanic',
#   'count': '1'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '40 - 49 Years',
#   'race_ethnicity_combined': 'Black, Non-Hispanic',
#   'count': '304'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '80+ Years',
#   'race_ethnicity_combined': 'Missing',
#   'count': '5'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '50 - 59 Years',
#   'race_ethnicity_combined': 'White, Non-Hispanic',
#   'count': '2'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '50 - 59 Years',
#   'race_ethnicity_combined': 'Missing',
#   'count': '66'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '30 - 39 Years',
#   'race_ethnicity_combined': 'American Indian/Alaska Native, Non-Hispanic',
#   'count': '23'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Missing',
#   'age_group': '20 - 29 Years',
#   'race_ethnicity_combined': 'Missing',
#   'count': '9'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '10 - 19 Years',
#   'race_ethnicity_combined': 'American Indian/Alaska Native, Non-Hispanic',
#   'count': '15'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '50 - 59 Years',
#   'race_ethnicity_combined': 'Missing',
#   'count': '52'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '60 - 69 Years',
#   'race_ethnicity_combined': 'Native Hawaiian/Other Pacific Islander, Non-Hispanic',
#   'count': '2'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '40 - 49 Years',
#   'race_ethnicity_combined': 'Black, Non-Hispanic',
#   'count': '349'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '40 - 49 Years',
#   'race_ethnicity_combined': 'Missing',
#   'count': '68'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '80+ Years',
#   'race_ethnicity_combined': 'Missing',
#   'count': '5'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '70 - 79 Years',
#   'race_ethnicity_combined': 'Black, Non-Hispanic',
#   'count': '39'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '60 - 69 Years',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '631'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '60 - 69 Years',
#   'race_ethnicity_combined': 'Black, Non-Hispanic',
#   'count': '172'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '50 - 59 Years',
#   'race_ethnicity_combined': 'American Indian/Alaska Native, Non-Hispanic',
#   'count': '16'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '70 - 79 Years',
#   'race_ethnicity_combined': 'Multiple/Other, Non-Hispanic',
#   'count': '38'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '50 - 59 Years',
#   'race_ethnicity_combined': 'Asian, Non-Hispanic',
#   'count': '91'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '80+ Years',
#   'race_ethnicity_combined': 'Hispanic/Latino',
#   'count': '45'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '50 - 59 Years',
#   'race_ethnicity_combined': 'Multiple/Other, Non-Hispanic',
#   'count': '148'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': 'Missing',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '10'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '0 - 9 Years',
#   'race_ethnicity_combined': 'Asian, Non-Hispanic',
#   'count': '67'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '60 - 69 Years',
#   'race_ethnicity_combined': 'American Indian/Alaska Native, Non-Hispanic',
#   'count': '8'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Missing',
#   'age_group': '30 - 39 Years',
#   'race_ethnicity_combined': 'White, Non-Hispanic',
#   'count': '3'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '0 - 9 Years',
#   'race_ethnicity_combined': 'Missing',
#   'count': '31'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '10 - 19 Years',
#   'race_ethnicity_combined': 'White, Non-Hispanic',
#   'count': '1227'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Missing',
#   'age_group': '10 - 19 Years',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '3'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '70 - 79 Years',
#   'race_ethnicity_combined': 'Native Hawaiian/Other Pacific Islander, Non-Hispanic',
#   'count': '1'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '0 - 9 Years',
#   'race_ethnicity_combined': 'Asian, Non-Hispanic',
#   'count': '46'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '70 - 79 Years',
#   'race_ethnicity_combined': 'American Indian/Alaska Native, Non-Hispanic',
#   'count': '3'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '20 - 29 Years',
#   'race_ethnicity_combined': 'Asian, Non-Hispanic',
#   'count': '117'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Missing',
#   'age_group': '70 - 79 Years',
#   'race_ethnicity_combined': 'Missing',
#   'count': '4'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '70 - 79 Years',
#   'race_ethnicity_combined': 'American Indian/Alaska Native, Non-Hispanic',
#   'count': '2'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '0 - 9 Years',
#   'race_ethnicity_combined': 'Multiple/Other, Non-Hispanic',
#   'count': '118'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '40 - 49 Years',
#   'race_ethnicity_combined': 'Native Hawaiian/Other Pacific Islander, Non-Hispanic',
#   'count': '4'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '70 - 79 Years',
#   'race_ethnicity_combined': 'Hispanic/Latino',
#   'count': '1'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Missing',
#   'age_group': '0 - 9 Years',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '13'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '60 - 69 Years',
#   'race_ethnicity_combined': 'Missing',
#   'count': '41'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': 'Missing',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '6'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '10 - 19 Years',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '34'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Missing',
#   'age_group': '10 - 19 Years',
#   'race_ethnicity_combined': 'Missing',
#   'count': '8'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '20 - 29 Years',
#   'race_ethnicity_combined': 'Hispanic/Latino',
#   'count': '685'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '60 - 69 Years',
#   'race_ethnicity_combined': 'Native Hawaiian/Other Pacific Islander, Non-Hispanic',
#   'count': '2'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '0 - 9 Years',
#   'race_ethnicity_combined': 'Native Hawaiian/Other Pacific Islander, Non-Hispanic',
#   'count': '1'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Missing',
#   'age_group': '0 - 9 Years',
#   'race_ethnicity_combined': 'Hispanic/Latino',
#   'count': '3'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '10 - 19 Years',
#   'race_ethnicity_combined': 'White, Non-Hispanic',
#   'count': '1177'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '30 - 39 Years',
#   'race_ethnicity_combined': 'Hispanic/Latino',
#   'count': '641'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '20 - 29 Years',
#   'race_ethnicity_combined': 'Native Hawaiian/Other Pacific Islander, Non-Hispanic',
#   'count': '6'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '80+ Years',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '2'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Missing',
#   'age_group': '20 - 29 Years',
#   'race_ethnicity_combined': 'White, Non-Hispanic',
#   'count': '7'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '10 - 19 Years',
#   'race_ethnicity_combined': 'Black, Non-Hispanic',
#   'count': '245'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '10 - 19 Years',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '1107'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '40 - 49 Years',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '1106'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '20 - 29 Years',
#   'race_ethnicity_combined': 'Multiple/Other, Non-Hispanic',
#   'count': '252'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '80+ Years',
#   'race_ethnicity_combined': 'Black, Non-Hispanic',
#   'count': '49'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Missing',
#   'age_group': '0 - 9 Years',
#   'race_ethnicity_combined': 'Asian, Non-Hispanic',
#   'count': '1'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '50 - 59 Years',
#   'race_ethnicity_combined': 'Hispanic/Latino',
#   'count': '463'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '10 - 19 Years',
#   'race_ethnicity_combined': 'Black, Non-Hispanic',
#   'count': '308'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '70 - 79 Years',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '204'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '30 - 39 Years',
#   'race_ethnicity_combined': 'Native Hawaiian/Other Pacific Islander, Non-Hispanic',
#   'count': '2'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '60 - 69 Years',
#   'race_ethnicity_combined': 'White, Non-Hispanic',
#   'count': '902'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '30 - 39 Years',
#   'race_ethnicity_combined': 'White, Non-Hispanic',
#   'count': '1315'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '80+ Years',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '101'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '0 - 9 Years',
#   'race_ethnicity_combined': 'Hispanic/Latino',
#   'count': '4'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '70 - 79 Years',
#   'race_ethnicity_combined': 'Missing',
#   'count': '9'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '60 - 69 Years',
#   'race_ethnicity_combined': 'Black, Non-Hispanic',
#   'count': '143'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '0 - 9 Years',
#   'race_ethnicity_combined': 'Hispanic/Latino',
#   'count': '271'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '50 - 59 Years',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '979'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '50 - 59 Years',
#   'race_ethnicity_combined': 'Asian, Non-Hispanic',
#   'count': '90'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '50 - 59 Years',
#   'race_ethnicity_combined': 'Asian, Non-Hispanic',
#   'count': '1'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '10 - 19 Years',
#   'race_ethnicity_combined': 'Asian, Non-Hispanic',
#   'count': '70'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '50 - 59 Years',
#   'race_ethnicity_combined': 'White, Non-Hispanic',
#   'count': '1325'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '80+ Years',
#   'race_ethnicity_combined': 'American Indian/Alaska Native, Non-Hispanic',
#   'count': '4'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '20 - 29 Years',
#   'race_ethnicity_combined': 'American Indian/Alaska Native, Non-Hispanic',
#   'count': '19'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': 'Missing',
#   'race_ethnicity_combined': 'Hispanic/Latino',
#   'count': '5'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '50 - 59 Years',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '31'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '20 - 29 Years',
#   'race_ethnicity_combined': 'Multiple/Other, Non-Hispanic',
#   'count': '278'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '30 - 39 Years',
#   'race_ethnicity_combined': 'Asian, Non-Hispanic',
#   'count': '1'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '70 - 79 Years',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '247'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Missing',
#   'age_group': '30 - 39 Years',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '2'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Missing',
#   'age_group': '40 - 49 Years',
#   'race_ethnicity_combined': 'Asian, Non-Hispanic',
#   'count': '1'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '10 - 19 Years',
#   'race_ethnicity_combined': 'American Indian/Alaska Native, Non-Hispanic',
#   'count': '24'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '40 - 49 Years',
#   'race_ethnicity_combined': 'American Indian/Alaska Native, Non-Hispanic',
#   'count': '15'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Missing',
#   'age_group': '20 - 29 Years',
#   'race_ethnicity_combined': 'Black, Non-Hispanic',
#   'count': '3'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Missing',
#   'age_group': 'Missing',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '2'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '10 - 19 Years',
#   'race_ethnicity_combined': 'Multiple/Other, Non-Hispanic',
#   'count': '4'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '0 - 9 Years',
#   'race_ethnicity_combined': 'American Indian/Alaska Native, Non-Hispanic',
#   'count': '9'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Missing',
#   'age_group': '20 - 29 Years',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '2'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '70 - 79 Years',
#   'race_ethnicity_combined': 'Multiple/Other, Non-Hispanic',
#   'count': '2'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Missing',
#   'age_group': '10 - 19 Years',
#   'race_ethnicity_combined': 'White, Non-Hispanic',
#   'count': '4'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '80+ Years',
#   'race_ethnicity_combined': 'Asian, Non-Hispanic',
#   'count': '7'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '40 - 49 Years',
#   'race_ethnicity_combined': 'Multiple/Other, Non-Hispanic',
#   'count': '196'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '50 - 59 Years',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '1111'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '20 - 29 Years',
#   'race_ethnicity_combined': 'Hispanic/Latino',
#   'count': '778'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Missing',
#   'age_group': '60 - 69 Years',
#   'race_ethnicity_combined': 'White, Non-Hispanic',
#   'count': '1'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '60 - 69 Years',
#   'race_ethnicity_combined': 'Hispanic/Latino',
#   'count': '245'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '0 - 9 Years',
#   'race_ethnicity_combined': 'Multiple/Other, Non-Hispanic',
#   'count': '98'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Missing',
#   'age_group': '0 - 9 Years',
#   'race_ethnicity_combined': 'Missing',
#   'count': '7'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '30 - 39 Years',
#   'race_ethnicity_combined': 'Native Hawaiian/Other Pacific Islander, Non-Hispanic',
#   'count': '2'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '40 - 49 Years',
#   'race_ethnicity_combined': 'Missing',
#   'count': '64'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '50 - 59 Years',
#   'race_ethnicity_combined': 'Multiple/Other, Non-Hispanic',
#   'count': '141'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '30 - 39 Years',
#   'race_ethnicity_combined': 'Asian, Non-Hispanic',
#   'count': '146'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '40 - 49 Years',
#   'race_ethnicity_combined': 'White, Non-Hispanic',
#   'count': '1185'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '20 - 29 Years',
#   'race_ethnicity_combined': 'American Indian/Alaska Native, Non-Hispanic',
#   'count': '21'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Other',
#   'age_group': '10 - 19 Years',
#   'race_ethnicity_combined': 'White, Non-Hispanic',
#   'count': '1'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '0 - 9 Years',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '486'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Missing',
#   'age_group': '0 - 9 Years',
#   'race_ethnicity_combined': 'White, Non-Hispanic',
#   'count': '8'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '60 - 69 Years',
#   'race_ethnicity_combined': 'Hispanic/Latino',
#   'count': '147'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '60 - 69 Years',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '9'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '80+ Years',
#   'race_ethnicity_combined': 'Asian, Non-Hispanic',
#   'count': '3'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '10 - 19 Years',
#   'race_ethnicity_combined': 'Hispanic/Latino',
#   'count': '488'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '20 - 29 Years',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '1692'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '30 - 39 Years',
#   'race_ethnicity_combined': 'Asian, Non-Hispanic',
#   'count': '126'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': 'Missing',
#   'race_ethnicity_combined': 'Asian, Non-Hispanic',
#   'count': '1'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '70 - 79 Years',
#   'race_ethnicity_combined': 'White, Non-Hispanic',
#   'count': '386'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '70 - 79 Years',
#   'race_ethnicity_combined': 'Hispanic/Latino',
#   'count': '96'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '50 - 59 Years',
#   'race_ethnicity_combined': 'Native Hawaiian/Other Pacific Islander, Non-Hispanic',
#   'count': '4'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '30 - 39 Years',
#   'race_ethnicity_combined': 'Missing',
#   'count': '3'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Missing',
#   'age_group': '0 - 9 Years',
#   'race_ethnicity_combined': 'Black, Non-Hispanic',
#   'count': '2'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '20 - 29 Years',
#   'race_ethnicity_combined': 'Hispanic/Latino',
#   'count': '3'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '60 - 69 Years',
#   'race_ethnicity_combined': 'Asian, Non-Hispanic',
#   'count': '56'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '80+ Years',
#   'race_ethnicity_combined': 'Multiple/Other, Non-Hispanic',
#   'count': '20'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '20 - 29 Years',
#   'race_ethnicity_combined': 'Missing',
#   'count': '2'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': 'Missing',
#   'race_ethnicity_combined': 'American Indian/Alaska Native, Non-Hispanic',
#   'count': '1'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Missing',
#   'age_group': '50 - 59 Years',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '2'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '0 - 9 Years',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '14'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '30 - 39 Years',
#   'race_ethnicity_combined': 'White, Non-Hispanic',
#   'count': '1'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '80+ Years',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '172'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '50 - 59 Years',
#   'race_ethnicity_combined': 'Native Hawaiian/Other Pacific Islander, Non-Hispanic',
#   'count': '2'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '50 - 59 Years',
#   'race_ethnicity_combined': 'Multiple/Other, Non-Hispanic',
#   'count': '1'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '30 - 39 Years',
#   'race_ethnicity_combined': 'White, Non-Hispanic',
#   'count': '1428'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '60 - 69 Years',
#   'race_ethnicity_combined': 'American Indian/Alaska Native, Non-Hispanic',
#   'count': '9'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': 'Missing',
#   'race_ethnicity_combined': 'Multiple/Other, Non-Hispanic',
#   'count': '1'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Missing',
#   'age_group': '20 - 29 Years',
#   'race_ethnicity_combined': 'Hispanic/Latino',
#   'count': '1'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '50 - 59 Years',
#   'race_ethnicity_combined': 'Missing',
#   'count': '1'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '30 - 39 Years',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '36'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '0 - 9 Years',
#   'race_ethnicity_combined': 'Black, Non-Hispanic',
#   'count': '173'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '40 - 49 Years',
#   'race_ethnicity_combined': 'Hispanic/Latino',
#   'count': '541'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Missing',
#   'age_group': '80+ Years',
#   'race_ethnicity_combined': 'Missing',
#   'count': '1'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Missing',
#   'age_group': '30 - 39 Years',
#   'race_ethnicity_combined': 'Missing',
#   'count': '15'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '50 - 59 Years',
#   'race_ethnicity_combined': 'White, Non-Hispanic',
#   'count': '1269'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Missing',
#   'age_group': '30 - 39 Years',
#   'race_ethnicity_combined': 'Multiple/Other, Non-Hispanic',
#   'count': '1'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Missing',
#   'age_group': '50 - 59 Years',
#   'race_ethnicity_combined': 'Missing',
#   'count': '6'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '20 - 29 Years',
#   'race_ethnicity_combined': 'Missing',
#   'count': '117'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '80+ Years',
#   'race_ethnicity_combined': 'Hispanic/Latino',
#   'count': '21'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '20 - 29 Years',
#   'race_ethnicity_combined': 'White, Non-Hispanic',
#   'count': '1655'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '30 - 39 Years',
#   'race_ethnicity_combined': 'Missing',
#   'count': '72'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '10 - 19 Years',
#   'race_ethnicity_combined': 'Native Hawaiian/Other Pacific Islander, Non-Hispanic',
#   'count': '4'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '10 - 19 Years',
#   'race_ethnicity_combined': 'Black, Non-Hispanic',
#   'count': '3'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '30 - 39 Years',
#   'race_ethnicity_combined': 'Multiple/Other, Non-Hispanic',
#   'count': '234'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '10 - 19 Years',
#   'race_ethnicity_combined': 'Missing',
#   'count': '67'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '70 - 79 Years',
#   'race_ethnicity_combined': 'Missing',
#   'count': '1'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '70 - 79 Years',
#   'race_ethnicity_combined': 'White, Non-Hispanic',
#   'count': '3'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '20 - 29 Years',
#   'race_ethnicity_combined': 'Asian, Non-Hispanic',
#   'count': '135'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '20 - 29 Years',
#   'race_ethnicity_combined': 'Black, Non-Hispanic',
#   'count': '539'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '40 - 49 Years',
#   'race_ethnicity_combined': 'White, Non-Hispanic',
#   'count': '4'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '40 - 49 Years',
#   'race_ethnicity_combined': 'Hispanic/Latino',
#   'count': '558'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '30 - 39 Years',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '1308'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '20 - 29 Years',
#   'race_ethnicity_combined': 'Missing',
#   'count': '101'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '40 - 49 Years',
#   'race_ethnicity_combined': 'Asian, Non-Hispanic',
#   'count': '101'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '70 - 79 Years',
#   'race_ethnicity_combined': 'Multiple/Other, Non-Hispanic',
#   'count': '34'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '20 - 29 Years',
#   'race_ethnicity_combined': 'White, Non-Hispanic',
#   'count': '7'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '80+ Years',
#   'race_ethnicity_combined': 'Multiple/Other, Non-Hispanic',
#   'count': '17'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '40 - 49 Years',
#   'race_ethnicity_combined': 'White, Non-Hispanic',
#   'count': '1244'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Missing',
#   'age_group': 'Missing',
#   'race_ethnicity_combined': 'Missing',
#   'count': '2'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '10 - 19 Years',
#   'race_ethnicity_combined': 'Multiple/Other, Non-Hispanic',
#   'count': '208'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '50 - 59 Years',
#   'race_ethnicity_combined': 'Black, Non-Hispanic',
#   'count': '220'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '30 - 39 Years',
#   'race_ethnicity_combined': 'Black, Non-Hispanic',
#   'count': '351'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '0 - 9 Years',
#   'race_ethnicity_combined': 'Native Hawaiian/Other Pacific Islander, Non-Hispanic',
#   'count': '1'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '70 - 79 Years',
#   'race_ethnicity_combined': 'Missing',
#   'count': '14'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Missing',
#   'age_group': '40 - 49 Years',
#   'race_ethnicity_combined': 'Missing',
#   'count': '10'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '10 - 19 Years',
#   'race_ethnicity_combined': 'Missing',
#   'count': '61'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '10 - 19 Years',
#   'race_ethnicity_combined': 'Hispanic/Latino',
#   'count': '3'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '80+ Years',
#   'race_ethnicity_combined': 'White, Non-Hispanic',
#   'count': '161'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '30 - 39 Years',
#   'race_ethnicity_combined': 'Multiple/Other, Non-Hispanic',
#   'count': '2'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '60 - 69 Years',
#   'race_ethnicity_combined': 'White, Non-Hispanic',
#   'count': '822'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '40 - 49 Years',
#   'race_ethnicity_combined': 'Asian, Non-Hispanic',
#   'count': '98'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '40 - 49 Years',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '1059'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '30 - 39 Years',
#   'race_ethnicity_combined': 'Black, Non-Hispanic',
#   'count': '534'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '0 - 9 Years',
#   'race_ethnicity_combined': 'Black, Non-Hispanic',
#   'count': '141'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Missing',
#   'age_group': '0 - 9 Years',
#   'race_ethnicity_combined': 'Multiple/Other, Non-Hispanic',
#   'count': '4'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '30 - 39 Years',
#   'race_ethnicity_combined': 'Hispanic/Latino',
#   'count': '574'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '40 - 49 Years',
#   'race_ethnicity_combined': 'Multiple/Other, Non-Hispanic',
#   'count': '189'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '70 - 79 Years',
#   'race_ethnicity_combined': 'Asian, Non-Hispanic',
#   'count': '25'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '80+ Years',
#   'race_ethnicity_combined': 'White, Non-Hispanic',
#   'count': '241'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '10 - 19 Years',
#   'race_ethnicity_combined': 'Multiple/Other, Non-Hispanic',
#   'count': '176'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '70 - 79 Years',
#   'race_ethnicity_combined': 'Asian, Non-Hispanic',
#   'count': '23'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '40 - 49 Years',
#   'race_ethnicity_combined': 'Black, Non-Hispanic',
#   'count': '1'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '10 - 19 Years',
#   'race_ethnicity_combined': 'White, Non-Hispanic',
#   'count': '3'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '0 - 9 Years',
#   'race_ethnicity_combined': 'Hispanic/Latino',
#   'count': '298'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '20 - 29 Years',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '59'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '20 - 29 Years',
#   'race_ethnicity_combined': 'Native Hawaiian/Other Pacific Islander, Non-Hispanic',
#   'count': '3'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '50 - 59 Years',
#   'race_ethnicity_combined': 'Black, Non-Hispanic',
#   'count': '297'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '70 - 79 Years',
#   'race_ethnicity_combined': 'Black, Non-Hispanic',
#   'count': '85'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '70 - 79 Years',
#   'race_ethnicity_combined': 'Hispanic/Latino',
#   'count': '66'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '0 - 9 Years',
#   'race_ethnicity_combined': 'Missing',
#   'count': '37'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '0 - 9 Years',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '492'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '60 - 69 Years',
#   'race_ethnicity_combined': 'Asian, Non-Hispanic',
#   'count': '53'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '60 - 69 Years',
#   'race_ethnicity_combined': 'Missing',
#   'count': '1'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '40 - 49 Years',
#   'race_ethnicity_combined': 'Native Hawaiian/Other Pacific Islander, Non-Hispanic',
#   'count': '4'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': 'Missing',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '15'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '0 - 9 Years',
#   'race_ethnicity_combined': 'White, Non-Hispanic',
#   'count': '1'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '30 - 39 Years',
#   'race_ethnicity_combined': 'Hispanic/Latino',
#   'count': '2'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': 'Missing',
#   'race_ethnicity_combined': 'White, Non-Hispanic',
#   'count': '7'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '0 - 9 Years',
#   'race_ethnicity_combined': 'White, Non-Hispanic',
#   'count': '497'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '20 - 29 Years',
#   'race_ethnicity_combined': 'White, Non-Hispanic',
#   'count': '1753'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '40 - 49 Years',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '29'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '20 - 29 Years',
#   'race_ethnicity_combined': 'Multiple/Other, Non-Hispanic',
#   'count': '5'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '50 - 59 Years',
#   'race_ethnicity_combined': 'American Indian/Alaska Native, Non-Hispanic',
#   'count': '16'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '0 - 9 Years',
#   'race_ethnicity_combined': 'American Indian/Alaska Native, Non-Hispanic',
#   'count': '5'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '10 - 19 Years',
#   'race_ethnicity_combined': 'Unknown',
#   'count': '1084'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '80+ Years',
#   'race_ethnicity_combined': 'Black, Non-Hispanic',
#   'count': '25'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '10 - 19 Years',
#   'race_ethnicity_combined': 'Native Hawaiian/Other Pacific Islander, Non-Hispanic',
#   'count': '3'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '10 - 19 Years',
#   'race_ethnicity_combined': 'Hispanic/Latino',
#   'count': '535'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Missing',
#   'age_group': '60 - 69 Years',
#   'race_ethnicity_combined': 'Missing',
#   'count': '5'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Unknown',
#   'age_group': '10 - 19 Years',
#   'race_ethnicity_combined': 'Missing',
#   'count': '2'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Male',
#   'age_group': '10 - 19 Years',
#   'race_ethnicity_combined': 'Asian, Non-Hispanic',
#   'count': '72'},
#  {'cdc_case_earliest_dt': '2021-04-01T00:00:00.000',
#   'sex': 'Female',
#   'age_group': '40 - 49 Years',
#   'race_ethnicity_combined': 'American Indian/Alaska Native, Non-Hispanic',
#   'count': '18'}]

# %%
import pyspark
from pyspark import SparkConf
from pyspark.sql import SparkSession

# %%
spark = SparkSession \
    .builder \
    .appName("spark_to_postgres") \
    .getOrCreate()

# %%
df = spark.read.json(spark.sparkContext.parallelize(cases_per_date))

# %%
df.printSchema()
# Out:
# root
#  |-- age_group: string (nullable = true)
#  |-- cdc_case_earliest_dt: string (nullable = true)
#  |-- count: string (nullable = true)
#  |-- race_ethnicity_combined: string (nullable = true)
#  |-- sex: string (nullable = true)

# %%
df.count()
# Out:
# 242

# %% [markdown]
# ## Quick analysis

# %%
set( [a["sex"] for a in res_sex_age_race_date])
# Out:
# {'Female', 'Male', 'Missing', 'NA', 'Other', 'Unknown'}

# %%
set( [a["age_group"] for a in res_sex_age_race_date])
# Out:
# {'0 - 9 Years',
#  '10 - 19 Years',
#  '20 - 29 Years',
#  '30 - 39 Years',
#  '40 - 49 Years',
#  '50 - 59 Years',
#  '60 - 69 Years',
#  '70 - 79 Years',
#  '80+ Years',
#  'Missing',
#  'NA'}

# %%
set( [a["race_ethnicity_combined"] for a in res_sex_age_race_date])
# Out:
# {'American Indian/Alaska Native, Non-Hispanic',
#  'Asian, Non-Hispanic',
#  'Black, Non-Hispanic',
#  'Hispanic/Latino',
#  'Missing',
#  'Multiple/Other, Non-Hispanic',
#  'NA',
#  'Native Hawaiian/Other Pacific Islander, Non-Hispanic',
#  'Unknown',
#  'White, Non-Hispanic'}

# %%
set( [a["death_yn"] for a in res_sex_age_ethnicity_death])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-e546da2d77dd> in <module>
# ----> 1 set( [a["death_yn"] for a in res_sex_age_ethnicity_death])
#
# NameError: name 'res_sex_age_ethnicity_death' is not defined

# %%
df_death = pd.DataFrame(res_sex_age_ethnicity_death)
df_death = df_death.astype({"count" : "int"})

# %%
df_death.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1320 entries, 0 to 1319
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   sex                      1320 non-null   object
#  1   age_group                1320 non-null   object
#  2   race_ethnicity_combined  1320 non-null   object
#  3   death_yn                 1320 non-null   object
#  4   count                    1320 non-null   int64
# dtypes: int64(1), object(4)
# memory usage: 51.7+ KB

# %%
df_death.groupby(["sex", "death_yn"]).sum()
# Out:
#                     count
# sex     death_yn
# Female  Missing   3846666
#         No        5489794
#         Unknown   1114997
#         Yes        169984
# Male    Missing   3534902
#         No        4939349
#         Unknown   1019183
#         Yes        201449
# Missing Missing     35643
#         No          12761
#         Unknown      2051
#         Yes           276
# NA      Missing         6
#         No              9
# Other   Missing       164
#         No            225
#         Unknown        14
#         Yes             6
# Unknown Missing    108058
#         No          75437
#         Unknown     13508
#         Yes           863

# %%
df_death.groupby(["sex", "death_yn"]).sum().loc[ (["Female", "Male"],["Yes", "No"]) ]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-7cd1aabb0782> in <module>
# ----> 1 df_death.groupby(["sex", "death_yn"]).sum().loc[ (["Female", "Male"],["Yes", "No"])]
#
# ~/anaconda3/envs/pyspark/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# ~/anaconda3/envs/pyspark/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1042     def _getitem_tuple(self, tup: Tuple):
#    1043         try:
# -> 1044             return self._getitem_lowerdim(tup)
#    1045         except IndexingError:
#    1046             pass
#
# ~/anaconda3/envs/pyspark/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     764         # we may have a nested tuples indexer here
#     765         if self._is_nested_tuple_indexer(tup):
# --> 766             return self._getitem_nested_tuple(tup)
#     767
#     768         # we maybe be using a tuple to represent multiple dimensions here
#
# ~/anaconda3/envs/pyspark/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_nested_tuple(self, tup)
#     845
#     846             current_ndim = obj.ndim
# --> 847             obj = getattr(obj, self.name)._getitem_axis(key, axis=axis)
#     848             axis += 1
#     849
#
# ~/anaconda3/envs/pyspark/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1097                     raise ValueError("Cannot index with multidimensional key")
#    1098
# -> 1099                 return self._getitem_iterable(key, axis=axis)
#    1100
#    1101             # nested tuple slicing
#
# ~/anaconda3/envs/pyspark/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1035
#    1036         # A collection of keys
# -> 1037         keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1038         return self.obj._reindex_with_indexers(
#    1039             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# ~/anaconda3/envs/pyspark/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ~/anaconda3/envs/pyspark/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1296             if missing == len(indexer):
#    1297                 axis_name = self.obj._get_axis_name(axis)
# -> 1298                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1299
#    1300             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['Yes', 'No'], dtype='object')] are in the [columns]"
